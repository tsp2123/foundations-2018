# %% [markdown]
# # Texas Tow Trucks
#
# We're going to scrape some [tow trucks in Texas](https://www.tdlr.texas.gov/tools_search/).

# %% [markdown]
# ## Import your imports

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

import pandas as pd

# %%
driver = webdriver.Chrome()

driver.get('https://www.tdlr.texas.gov/tools_search/')

# %%
text_input = driver.find_element_by_id('mcrdata')

text_input.send_keys('006179570C')

button = driver.find_element_by_id('submit3')

button.click()

# %% [markdown]
# ## Search for the TLDR Number `006179570C`, and scrape the information on that company
#
# Using [license information system](https://www.tdlr.texas.gov/tools_search/), find information about the tow truck number above, displaying the
#
# - The business name
# - Owner/operator
# - Phone number
# - License status (Active, Expired, Etc)
# - Physical address
#
# If you can't figure a 'nice' way to locate something, your two last options might be:
#
# - **Find a "parent" element, then dig inside**
# - **Find all of a type of element** (like we did with `td` before) and get the `[0]`, `[1]`, `[2]`, etc
# - **XPath** (inspect an element, Copy > Copy XPath)
#
# These kinds of techniques tend to break when you're on other result pages, but... maybe not! You won't know until you try.
#
# > - *TIP: When you use xpath, you CANNOT use double quotes or Python will get confused. Use single quotes.*
# > - *TIP: You can clean your data up if you want to, or leave it dirty to clean later*
# > - *TIP: The address part can be tough, but you have a few options. You can use a combination of `.split` and list slicing to clean it now, or clean it later in the dataframe with regular expressions. Or other options, too, probably*

# %%
name = driver.find_elements_by_tag_name('td')[5].text

# %%
owner = driver.find_elements_by_tag_name('td')[7].text

# %%
phone = driver.find_elements_by_tag_name('td')[9].text

# %%
status = driver.find_elements_by_tag_name('td')[12].text

# %%
license_number = driver.find_elements_by_tag_name('td')[13].text

# %%
information_table = driver.find_elements_by_tag_name('table')[4]

# %%
information_table.text
# Out:
# 'Certificate Information: Status:  Expired\nNumber:  006179570C (Expired) Carrier Type:  Tow Truck Company\nNumber of Active Tow Trucks:   0\n\nAddress Information\nMailing:\n13619 BRETT JACKSON RD\nFORT WORTH, TX. 76179\n\nPhysical:\n13619 BRETT JACKSON RD.\nFORT WORTH, TX. 76179'

# %%
address = information_table.find_elements_by_tag_name('tr')[1].find_elements_by_tag_name("td")[1].text

# %%
address.split('\n')[-2:]
# Out:
# ['13619 BRETT JACKSON RD.', 'FORT WORTH, TX. 76179']

# %% [markdown]
# # Adapt this to work inside of a single cell
#
# Double-check that it works. You want it to print out all of the details.

# %%
license_data = []

row = {}

row['name'] = driver.find_elements_by_tag_name('td')[5].text
row['owner'] = driver.find_elements_by_tag_name('td')[7].text
row['phone'] = driver.find_elements_by_tag_name('td')[9].text
row['status'] = driver.find_elements_by_tag_name('td')[12].text
row['license_number'] = driver.find_elements_by_tag_name('td')[13].text
row['address'] = address.split('\n')[-2:]

license_data.append(row)

license_data
# Out:
# [{'name': 'Name:   B.D. SMITH TOWING',
#   'owner': 'Owner/Officer:   BRANDT SMITH / OWNER',
#   'phone': 'Phone:   8173330706',
#   'status': 'Status:  Expired',
#   'license_number': 'Number:  006179570C (Expired)',
#   'address': ['13619 BRETT JACKSON RD.', 'FORT WORTH, TX. 76179']}]

# %% [markdown]
# # Using .apply to find data about SEVERAL tow truck companies
#
# The file `trucks-subset.csv` has information about the trucks, we'll use it to find the pages to scrape.
#
# ### Open up `trucks-subset.csv` and save it into a dataframe

# %%
pd.read_csv('trucks-subset.csv')
# Out:
#   TDLR Number
# 0  006507931C
# 1  006179570C
# 2  006502097C

# %%
df = pd.read_csv('trucks-subset.csv')

# %%
df.head()
# Out:
#   TDLR Number
# 0  006507931C
# 1  006179570C
# 2  006502097C

# %% [markdown]
# ## Go through each row of the dataset, displaying the URL you will need to scrape for the information on that row
#
# You don't have to actually use the search form for each of these - look at the URL you're on, it has the number in it!
#
# For example, one URL might look like `https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006495492C`.
#
# - *TIP: Use .apply and a function*
# - *TIP: Unlike the Yelp example, you'll need to build this URL from pieces*
# - *TIP: You probably don't want to `print` unless you're going to fix it for the next question
# - *TIP: pandas won't showing you the entire url! Run `pd.set_option('display.max_colwidth', -1)` to display aaaalll of the text in a cell*

# %%
# def get_yelp_info(row):
#     driver.get("https://www.yelp.com/biz/" + row['slug'])

#     store_name = driver.find_element_by_class_name("biz-page-title").text
#     full_address = driver.find_element_by_class_name("street-address").text
#     stars = driver.find_element_by_class_name("i-stars").get_attribute('title')
#     categories = driver.find_element_by_class_name("category-str-list").text

#     return pd.Series({
#         'store_name': store_name,
#         'address': full_address,
#         'stars': stars,
#         'categories': categories
#     })

# %%
# # Open up a new Chrome
# driver = webdriver.Chrome()

# # Take every row and send it to get_yelp_info, and combine with old data
# new_df = df.apply(get_yelp_info, axis=1).join(df)
# new_df.head()

# %%
def get_tdlr(row):
        url = ('https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=' + row['TDLR Number'])
        
        return url

# %%
pd.set_option('display.max_colwidth', -1)

# %%
#new_df = df.apply(get_tdlr, axis=1).join(df)
df
# Out:
#   TDLR Number
# 0  006507931C
# 1  006179570C
# 2  006502097C

# %% [markdown]
# ### Save this URL into a new column of your dataframe, called `url`
#
# - *TIP: Use a function and `.apply`*
# - *TIP: Be sure to use `return`*

# %%
df['url'] = df.apply(get_tdlr , axis=1)


df
# Out:
#   TDLR Number  \
# 0  006507931C
# 1  006179570C
# 2  006502097C
#
#                                                                              url
# 0  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006507931C
# 1  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006179570C
# 2  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006502097C

# %% [markdown]
# ## Go through each row of the dataset, printing out information about each tow truck company.
#
# Now will be **scraping** inside of your function.
#
# - The business name
# - Owner/operator
# - Phone number
# - License status (Active, Expired, Etc)
# - Physical address
#
# Just print it out for now.
#
# - *TIP: use .apply*
# - *TIP: You'll be using the code you wrote before, but converted into a function*
# - *TIP: Remember how the TDLR Number is in the URL? You don't need to do the form submission if you don't want!*
# - *TIP: Make sure you adjust any variables so you don't scrape the same page again and again*

# %%
def truck_scraper(row):
    driver.get(row['url'])
    
    name = driver.find_elements_by_tag_name('td')[5].text
    owner = driver.find_elements_by_tag_name('td')[7].text
    phone = driver.find_elements_by_tag_name('td')[9].text
    status = driver.find_elements_by_tag_name('td')[12].text
    license_number = driver.find_elements_by_tag_name('td')[13].text
    
    information_table = driver.find_elements_by_tag_name('table')[4]
    address = information_table.find_elements_by_tag_name('tr')[1].find_elements_by_tag_name("td")[1].text
    address = address.split('\n')[-2:]
    
    return pd.Series({
        'name': name,
        'owner': owner,
        'phone': phone,
        'status': status,
        'license_number': license_number,
        'address': address
     })

# %%
driver.find_elements_by_tag_name('td')[5].text
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-39-f27227959e90> in <module>()
# ----> 1 driver.find_elements_by_tag_name('td')[5].text
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_elements_by_tag_name(self, name)
#     537             elements = driver.find_elements_by_tag_name('h1')
#     538         """
# --> 539         return self.find_elements(by=By.TAG_NAME, value=name)
#     540
#     541     def find_element_by_class_name(self, name):
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_elements(self, by, value)
#     983         return self.execute(Command.FIND_ELEMENTS, {
#     984             'using': by,
# --> 985             'value': value})['value'] or []
#     986
#     987     @property
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     312         response = self.command_executor.execute(driver_command, params)
#     313         if response:
# --> 314             self.error_handler.check_response(response)
#     315             response['value'] = self._unwrap_value(
#     316                 response.get('value', None))
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.40.565386 (45a059dc425e08165f9a10324bd1380cc13ca363),platform=Mac OS X 10.13.3 x86_64)

# %% [markdown]
# ## Scrape the following information for each row of the dataset, and save it into new columns in your dataframe.
#
# - The business name
# - Owner/operator
# - Phone number
# - License status (Active, Expired, Etc)
# - Physical address
#
# It's basically what we did before, but using the function a little differently.
#
# - *TIP: Same as above, but you'll be returning a `pd.Series` and the `.apply` line is going to be a lot longer*
# - *TIP: Save it to a new dataframe!*
# - *TIP: Make sure you change your `df` variable names correctly if you're cutting and pasting - there are a few so it can get tricky*

# %%
trucks = df.apply(truck_scraper , axis=1)

# %%
trucks
# Out:
#                           name  \
# 0  Name:   AUGUSTUS E SMITH
# 1  Name:   B.D. SMITH TOWING
# 2  Name:   BARRY MICHAEL SMITH
#
#                                             owner                phone  \
# 0  Owner/Officer:   AUGUSTUS EUGENE SMITH / OWNER  Phone:   9032276464
# 1  Owner/Officer:   BRANDT SMITH / OWNER           Phone:   8173330706
# 2  Owner/Officer:   BARRY MICHAEL SMITH / OWNER    Phone:   8066544404
#
#              status                 license_number  \
# 0  Status:  Active   Number:  006507931C (Active)
# 1  Status:  Expired  Number:  006179570C (Expired)
# 2  Status:  Active   Number:  006502097C (Active)
#
#                                             address
# 0  [103 N MAIN ST, BONHAM, TX. 75418]
# 1  [13619 BRETT JACKSON RD., FORT WORTH, TX. 76179]
# 2  [4501 W CEMETERY RD, CANYON, TX. 79015]

# %% [markdown]
# ### Save your dataframe as a CSV named `tow-trucks-extended.csv`

# %%
trucks.to_csv("tow-trucks-extended.csv" , index=False)

# %% [markdown]
# ### Re-open your dataframe to confirm you didn't save any extra weird columns

# %%
pd.read_csv('tow-trucks-extended.csv')
# Out:
#                           name  \
# 0  Name:   AUGUSTUS E SMITH
# 1  Name:   B.D. SMITH TOWING
# 2  Name:   BARRY MICHAEL SMITH
#
#                                             owner                phone  \
# 0  Owner/Officer:   AUGUSTUS EUGENE SMITH / OWNER  Phone:   9032276464
# 1  Owner/Officer:   BRANDT SMITH / OWNER           Phone:   8173330706
# 2  Owner/Officer:   BARRY MICHAEL SMITH / OWNER    Phone:   8066544404
#
#              status                 license_number  \
# 0  Status:  Active   Number:  006507931C (Active)
# 1  Status:  Expired  Number:  006179570C (Expired)
# 2  Status:  Active   Number:  006502097C (Active)
#
#                                                 address
# 0  ['103 N MAIN ST', 'BONHAM, TX. 75418']
# 1  ['13619 BRETT JACKSON RD.', 'FORT WORTH, TX. 76179']
# 2  ['4501 W CEMETERY RD', 'CANYON, TX. 79015']

# %% [markdown]
# ## Process the entire `tow-trucks.csv` file
#
# We just did it on a short subset so far. Now try it on all of the tow trucks. **Save as the same filename as before**

# %%
pd.read_csv('tow-trucks.csv')
# Out:
#     Unnamed: 0 TDLR Number
# 0   0           006507931C
# 1   1           006179570C
# 2   2           006502097C
# 3   3           006494912C
# 4   4           0649468VSF
# 5   5           006448786C
# 6   6           0648444VSF
# 7   7           0651667VSF
# 8   8           006017767C
# 9   9           006495492C
# 10  10          006518521C
# 11  11          006521662C
# 12  12          006482451C
# 13  13          0646264VSF
# 14  14          0650690VSF
# 15  15          006505010C
# 16  16          0000210VSF
# 17  17          005029369C
# 18  18          006410509C
# 19  19          0643482VSF

# %%
df = pd.read_csv('tow-trucks.csv')

# %%
df
# Out:
#     Unnamed: 0 TDLR Number
# 0   0           006507931C
# 1   1           006179570C
# 2   2           006502097C
# 3   3           006494912C
# 4   4           0649468VSF
# 5   5           006448786C
# 6   6           0648444VSF
# 7   7           0651667VSF
# 8   8           006017767C
# 9   9           006495492C
# 10  10          006518521C
# 11  11          006521662C
# 12  12          006482451C
# 13  13          0646264VSF
# 14  14          0650690VSF
# 15  15          006505010C
# 16  16          0000210VSF
# 17  17          005029369C
# 18  18          006410509C
# 19  19          0643482VSF

# %%
df['url'] = df.apply(get_tdlr , axis=1)

# %%
df
# Out:
#     Unnamed: 0 TDLR Number  \
# 0   0           006507931C
# 1   1           006179570C
# 2   2           006502097C
# 3   3           006494912C
# 4   4           0649468VSF
# 5   5           006448786C
# 6   6           0648444VSF
# 7   7           0651667VSF
# 8   8           006017767C
# 9   9           006495492C
# 10  10          006518521C
# 11  11          006521662C
# 12  12          006482451C
# 13  13          0646264VSF
# 14  14          0650690VSF
# 15  15          006505010C
# 16  16          0000210VSF
# 17  17          005029369C
# 18  18          006410509C
# 19  19          0643482VSF
#
#                                                                               url
# 0   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006507931C
# 1   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006179570C
# 2   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006502097C
# 3   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006494912C
# 4   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0649468VSF
# 5   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006448786C
# 6   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0648444VSF
# 7   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0651667VSF
# 8   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006017767C
# 9   https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006495492C
# 10  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006518521C
# 11  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006521662C
# 12  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006482451C
# 13  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0646264VSF
# 14  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0650690VSF
# 15  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006505010C
# 16  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0000210VSF
# 17  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=005029369C
# 18  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=006410509C
# 19  https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=0643482VSF

# %%
trucks = df.apply(truck_scraper , axis=1)

# %%
trucks
# Out:
#                                              name  \
# 0   Name:   AUGUSTUS E SMITH
# 1   Name:   B.D. SMITH TOWING
# 2   Name:   BARRY MICHAEL SMITH
# 3   Name:   HEATH SMITH
# 4   Name:   HEATH SMITH
# 5   Name:   HYSMITH AUTOMOTIVE
# 6   Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 7   Name:   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 8   Name:   JEFF & WENDY SMITH
# 9   Name:   JEFF SMITH
# 10  Name:   LUTHER SMITH
# 11  Name:   MAURICE SMITH
# 12  Name:   METRO LOCKSMITHS INC
# 13  Name:   RICKY SMITH
# 14  Name:   RICKY SMITH
# 15  Name:   SAMMY L SMITH
# 16  Name:   SMITH BRO. WRECKER SERVICE
# 17  Name:   SMITH BROS. WRECKER SERVICE
# 18  Name:   SMITH TOWING & RECOVERY, LLC
# 19  Name:   SMITH TOWING & RECOVERY,LLC
#
#                                                   owner  \
# 0   Owner/Officer:   AUGUSTUS EUGENE SMITH / OWNER
# 1   Owner/Officer:   BRANDT SMITH / OWNER
# 2   Owner/Officer:   BARRY MICHAEL SMITH / OWNER
# 3   Owner/Officer:   HEATH A SMITH / OWNER
# 4   Owner/Officer:   HEATH A SMITH / OWNER
# 5   Owner/Officer:   WILLIAM THOMAS HYSMITH / PRESIDENT
# 6   Owner/Officer:   HYSMITH ERIN ASHLEY / TREASURER
# 7   Owner/Officer:   WILLIAM THOMAS HYSMITH / PRESIDENT
# 8   Owner/Officer:   JEFF SMITH / PARTNER
# 9   Owner/Officer:   JEFFREY JOHN SMITH / OWNER
# 10  Owner/Officer:   LUTHER EUGENE SMITH / OWNER
# 11  Owner/Officer:   MAURICE SMITH / OWNER
# 12  Owner/Officer:   ESTHER ENRIQUEZ / MANAGER
# 13  Owner/Officer:   RICKY SMITH / OWNER
# 14  Owner/Officer:   RICKY SMITH / OWNER
# 15  Owner/Officer:   SAMMY LEE SMITH / OWNER
# 16  Owner/Officer:   JEFF SMITH / PARTNER
# 17  Owner/Officer:   JEFF SMITH / PARTNER
# 18  Owner/Officer:   RICKY L SMITH / OWNER
# 19  Owner/Officer:   RICKY L SMITH / CEO
#
#                                                   phone  \
# 0   Phone:   9032276464
# 1   Phone:   8173330706
# 2   Phone:   8066544404
# 3   Phone:   940-552-0687
# 4   Phone:   9405520687
# 5   Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER
# 6   Owner/Officer:   WILLIAM THOMAS HYSMITH / PRESIDENT
# 7   Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER
# 8   Owner/Officer:   WENDY SMITH / PARTNER
# 9   Phone:   8324354670
# 10  Phone:   281-838-9435
# 11  Phone:   7134544462
# 12  Owner/Officer:   SOCORRO M ARREOLA / OWNER
# 13  Phone:   9364997917
# 14  Phone:   9364997917
# 15  Phone:   3252159496
# 16  Owner/Officer:   GLEN SMITH / PARTNER
# 17  Owner/Officer:   GLEN SMITH / PARTNER
# 18  Phone:   9362693915
# 19  Phone:   9362693915
#
#                                         status  \
# 0   Status:  Active
# 1   Status:  Expired
# 2   Status:  Active
# 3   Status:  Expired
# 4   Status:  Expired
# 5
# 6
# 7
# 8
# 9   Status:  Active
# 10  Status:  Insurance and/or fees not applied
# 11  Status:  Active
# 12
# 13  Status:  Suspended
# 14  Status:  Suspended
# 15  Status:  Expired
# 16
# 17
# 18  Status:  Active
# 19  Status:  Active
#
#                                              license_number  \
# 0   Number:  006507931C (Active)
# 1   Number:  006179570C (Expired)
# 2   Number:  006502097C (Active)
# 3   Number:  006494912C (Expired)
# 4   Number:  0649468VSF (Expired)
# 5   Certificate Information:
# 6   Certificate Information:
# 7   Certificate Information:
# 8   Certificate Information:
# 9   Number:  006495492C (Active)
# 10  Number:  006518521C (Insurance and/or fees not applied)
# 11  Number:  006521662C (Active)
# 12  Certificate Information:
# 13  Number:  0646264VSF (Suspended)
# 14  Number:  0650690VSF (Suspended)
# 15  Number:  006505010C (Expired)
# 16  Certificate Information:
# 17  Certificate Information:
# 18  Number:  006410509C (Active)
# 19  Number:  0643482VSF (Active)
#
#                                              address
# 0   [103 N MAIN ST, BONHAM, TX. 75418]
# 1   [13619 BRETT JACKSON RD., FORT WORTH, TX. 76179]
# 2   [4501 W CEMETERY RD, CANYON, TX. 79015]
# 3   [1529 WILBARGER ST, VERNON, TX. 76384]
# 4   [1529 WILBARGER ST, VERNON, TX. 76384]
# 5   [1210 US 380 BYPASS, GRAHAM, TX. 76450]
# 6   [927 LOVING HWY, GRAHAM, TX. 76450]
# 7   [1210 380 BYPASS, GRAHAM, TX. 76450]
# 8   [10842 FM 2138 N, JACKSONVILLE, TX. 75766]
# 9   [4338 HARVEY RD, CROSBY, TX. 77532]
# 10  [20001 FM 2100 RD, CROSBY, TX. 77532]
# 11  [5505 SAVANNAH WOODS LN, ROSHARON, TX. 77583]
# 12  [200 S WALL ST, ITASCA, TX. 76055]
# 13  [115 CARTWRIGHT, CONROE, TX. 77301]
# 14  [11426 FOSTORIA RD, CLEVELAND, TX. 77328]
# 15  [355 N 16TH ST, JUNCTION, TX. 76849]
# 16  [10842 FM 2138 N, JACKSONVILLE, TX. 75766]
# 17  [10842 FM 2138 N, JACKSONVILLE, TX. 75766]
# 18  [12741 HWY 84E, JOAQUIN, TX. 75954]
# 19  [12741 HWY 84 E, JOAQUIN, TX. 75954]
