# %%
import pandas as pd

# %%
import re

# %%
workers = pd.ExcelFile('/Users/TekendraMBP/Documents/Lede_Program/Databases/Final_Project/Percent_Members_of_Union/Percent_Members_of_Union_2.xlsx')

# %%
workers.sheet_names
# Out:
# ['BLS Data Series']

# %%
df = workers.parse('BLS Data Series')

pd.set_option('display.max_colwidth', 100)

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                        Original Data Value
# 1                                                        NaN
# 2                                                 Series Id:
# 3                                              Series title:
# 4                                          Unadjusted series
# 5                                                     Union:
# 6                                                  Industry:
# 7                                                Occupation:
# 8                                                       Sex:
# 9                                                      Race:
# 10                                            Ethnic Origin:
# 11                                                      Age:
# 12                                                 Earnings:
# 13                                          Class of Worker:
# 14                                       Labor force status:
# 15                                                    Years:
# 16                                                       NaN
# 17                                                      Year
# 18                                                      2000
# 19                                                      2001
# 20                                                      2002
# 21                                                      2003
# 22                                                      2004
# 23                                                      2005
# 24                                                      2006
# 25                                                      2007
# 26                                                      2008
# 27                                                      2009
# 28                                                      2010
# 29                                                      2011
# 30                                                      2012
# 31                                                      2013
# 32                                                      2014
# 33                                                      2015
# 34                                                      2016
#
#                                                        Unnamed: 1  Unnamed: 2  \
# 0                                                             NaN         NaN
# 1                                                             NaN         NaN
# 2                                                   LUU0204899601         NaN
# 3   (unadj)- Percent of employed, Members of unions, (AL) Alabama         NaN
# 4                                                             NaN         NaN
# 5                                               Members of unions         NaN
# 6                                                  All Industries         NaN
# 7                                                 All Occupations         NaN
# 8                                                      Both Sexes         NaN
# 9                                                       All Races         NaN
# 10                                                    All Origins         NaN
# 11                                              16 years and over         NaN
# 12                            Person counts (number in thousands)         NaN
# 13  Wage and salary workers, excluding incorporated self employed         NaN
# 14                                                       Employed         NaN
# 15                                                   2000 to 2016         NaN
# 16                                                            NaN         NaN
# 17                                                         Annual         NaN
# 18                                                            9.6         NaN
# 19                                                             10         NaN
# 20                                                            9.1         NaN
# 21                                                            8.1         NaN
# 22                                                            9.7         NaN
# 23                                                           10.2         NaN
# 24                                                            8.8         NaN
# 25                                                            9.5         NaN
# 26                                                            9.8         NaN
# 27                                                           10.9         NaN
# 28                                                           10.1         NaN
# 29                                                             10         NaN
# 30                                                            9.2         NaN
# 31                                                           10.7         NaN
# 32                                                           10.8         NaN
# 33                                                           10.2         NaN
# 34                                                            8.1         NaN
#
#     Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# 23         NaN         NaN         NaN
# 24         NaN         NaN         NaN
# 25         NaN         NaN         NaN
# 26         NaN         NaN         NaN
# 27         NaN         NaN         NaN
# 28         NaN         NaN         NaN
# 29         NaN         NaN         NaN
# 30         NaN         NaN         NaN
# 31         NaN         NaN         NaN
# 32         NaN         NaN         NaN
# 33         NaN         NaN         NaN
# 34         NaN         NaN         NaN

# %%
#Drop Columns 2 - 5

df.drop(columns='Unnamed: 2', inplace=True)
df.drop(columns='Unnamed: 3', inplace=True)
df.drop(columns='Unnamed: 4', inplace=True)
df.drop(columns='Unnamed: 5', inplace=True)


# # Step Two: Create a new column 'Years' # # 

df['Years'] = df['Union affiliation data from the Current Population Survey'][18:]

# # Step Three: Create a new column 'Percent_Represented' # #

df['Percent_Members'] = df['Unnamed: 1'][18:]

# # Step Four: Create a value for "Series Title" # #

df['Series_Title'] = df['Unnamed: 1'][3] 

# # Step 5: Create a column for Union # # 

df['Union'] = df['Unnamed: 1'][5] 

# # Step Six: Make a column for Industry # # 

df['Industry'] = df['Unnamed: 1'][6] 

# # Step Seven: Make a column for Earnings # #

df['Earnings'] = df['Unnamed: 1'][12] 

# # Step Eight: Make a column for Class of Workers # #

df['Class_of_Worker'] = df['Unnamed: 1'][13] 

# # Step Eight: This seems good, but get rid of the NaN values and narrow down your rows  # #

df = df.iloc[18:]

# # Step Nine: You can also drop those columns Union Affliation Data and Unnamed 1 Now. We got what we needed # #

df.drop(columns="Union affiliation data from the Current Population Survey" , inplace=True)

df.drop(columns='Unnamed: 1' , inplace=True)

# # Step Ten: Wouldn't it be nice to reset your index? Figure out how to do that.

df = df.reset_index(drop=True)

# # Step Eleven: Eventually we're going to need to geocode. Let's get the State's Acronymn in one column and State Name in another column. Be careful and make sure this step can work on several different states. 
# Name the State's acronymn "STUSPS" 
# Name the State's name "State"

df['STUSPS'] = df['Series_Title'].str.extract(r' \((\w\w)\)')

df['State'] = df['Series_Title'].str.extract(r'\(\w\w\)(.*)')

# # Step Twelve: Great Job! Let's save this as a CSV and make anew ipynb where I right a function to do this

state = df.at[1, 'State']

df.to_csv(str(state) + "_Members_of_Union.csv" , index=False)
# Out:
# /Users/TekendraMBP/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
