# %%
import pandas as pd

# %%
Alabama = pd.read_csv('/Users/TekendraMBP/Documents/Lede_Program/Databases/Final_Project/Members_of_Union_CSV/Alabama_Members_of_Union.csv')

# %%
Alabama
# Out:
#     Years  Percent_Members                                       Series_Title  \
# 0    2000              9.6  (unadj)- Percent of employed, Members of union...
# 1    2001             10.0  (unadj)- Percent of employed, Members of union...
# 2    2002              9.1  (unadj)- Percent of employed, Members of union...
# 3    2003              8.1  (unadj)- Percent of employed, Members of union...
# 4    2004              9.7  (unadj)- Percent of employed, Members of union...
# 5    2005             10.2  (unadj)- Percent of employed, Members of union...
# 6    2006              8.8  (unadj)- Percent of employed, Members of union...
# 7    2007              9.5  (unadj)- Percent of employed, Members of union...
# 8    2008              9.8  (unadj)- Percent of employed, Members of union...
# 9    2009             10.9  (unadj)- Percent of employed, Members of union...
# 10   2010             10.1  (unadj)- Percent of employed, Members of union...
# ...

# %%
Alaska = pd.read_csv('/Users/TekendraMBP/Documents/Lede_Program/Databases/Final_Project/Members_of_Union_CSV/Alaska_Members_of_Union.csv')

# %%
Alaska
# Out:
#     Years  Percent_Members                                       Series_Title  \
# 0    2000             21.6  (unadj)- Percent of employed, Members of union...
# 1    2001             21.5  (unadj)- Percent of employed, Members of union...
# 2    2002             24.4  (unadj)- Percent of employed, Members of union...
# 3    2003             22.3  (unadj)- Percent of employed, Members of union...
# 4    2004             20.1  (unadj)- Percent of employed, Members of union...
# 5    2005             22.8  (unadj)- Percent of employed, Members of union...
# 6    2006             22.2  (unadj)- Percent of employed, Members of union...
# 7    2007             23.8  (unadj)- Percent of employed, Members of union...
# 8    2008             23.5  (unadj)- Percent of employed, Members of union...
# 9    2009             22.3  (unadj)- Percent of employed, Members of union...
# 10   2010             22.9  (unadj)- Percent of employed, Members of union...
# ...

# %%
df = Ala

# %%
df
# Out:
#     Years  Percent_Members                                       Series_Title  \
# 0    2000              9.6  (unadj)- Percent of employed, Members of union...
# 1    2001             10.0  (unadj)- Percent of employed, Members of union...
# 2    2002              9.1  (unadj)- Percent of employed, Members of union...
# 3    2003              8.1  (unadj)- Percent of employed, Members of union...
# 4    2004              9.7  (unadj)- Percent of employed, Members of union...
# 5    2005             10.2  (unadj)- Percent of employed, Members of union...
# 6    2006              8.8  (unadj)- Percent of employed, Members of union...
# 7    2007              9.5  (unadj)- Percent of employed, Members of union...
# 8    2008              9.8  (unadj)- Percent of employed, Members of union...
# 9    2009             10.9  (unadj)- Percent of employed, Members of union...
# 10   2010             10.1  (unadj)- Percent of employed, Members of union...
# ...
