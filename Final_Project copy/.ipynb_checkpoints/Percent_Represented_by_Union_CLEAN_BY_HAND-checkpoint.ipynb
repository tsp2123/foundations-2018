# %%
import pandas as pd

# %%
import re

# %%
workers = pd.ExcelFile('/Users/TekendraMBP/Documents/Lede_Program/Databases/Final_Project/Percent_Represented_by_Unions/Percent_Represented_by_Unions_2.xlsx')

# %%
workers.sheet_names
# Out:
# ['BLS Data Series']

# %%
df = workers.parse('BLS Data Series')

pd.set_option('display.max_colwidth', 100)

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                        Original Data Value
# 1                                                        NaN
# 2                                                 Series Id:
# 3                                              Series title:
# 4                                          Unadjusted series
# 5                                                     Union:
# 6                                                  Industry:
# 7                                                Occupation:
# 8                                                       Sex:
# 9                                                      Race:
# 10                                            Ethnic Origin:
# 11                                                      Age:
# 12                                                 Earnings:
# 13                                          Class of Worker:
# 14                                       Labor force status:
# 15                                                    Years:
# 16                                                       NaN
# 17                                                      Year
# 18                                                      2000
# 19                                                      2001
# 20                                                      2002
# 21                                                      2003
# 22                                                      2004
# 23                                                      2005
# 24                                                      2006
# 25                                                      2007
# 26                                                      2008
# 27                                                      2009
# 28                                                      2010
# 29                                                      2011
# 30                                                      2012
# 31                                                      2013
# 32                                                      2014
# 33                                                      2015
# 34                                                      2016
#
#                                                            Unnamed: 1  \
# 0                                                                 NaN
# 1                                                                 NaN
# 2                                                       LUU0204899701
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 4                                                                 NaN
# 5                                               Represented by unions
# 6                                                      All Industries
# 7                                                     All Occupations
# 8                                                          Both Sexes
# 9                                                           All Races
# 10                                                        All Origins
# 11                                                  16 years and over
# 12                                Person counts (number in thousands)
# 13      Wage and salary workers, excluding incorporated self employed
# 14                                                           Employed
# 15                                                       2000 to 2016
# 16                                                                NaN
# 17                                                             Annual
# 18                                                               10.5
# 19                                                               11.3
# 20                                                               10.6
# 21                                                                9.5
# 22                                                               11.5
# 23                                                               11.7
# 24                                                                 10
# 25                                                               10.6
# 26                                                               10.7
# 27                                                                 12
# 28                                                               11.2
# 29                                                               10.8
# 30                                                               10.5
# 31                                                               11.7
# 32                                                               12.1
# 33                                                                 11
# 34                                                                  9
#
#     Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN
# 20         NaN         NaN         NaN         NaN
# 21         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN
# 23         NaN         NaN         NaN         NaN
# 24         NaN         NaN         NaN         NaN
# 25         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN
# 27         NaN         NaN         NaN         NaN
# 28         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN
# 30         NaN         NaN         NaN         NaN
# 31         NaN         NaN         NaN         NaN
# 32         NaN         NaN         NaN         NaN
# 33         NaN         NaN         NaN         NaN
# 34         NaN         NaN         NaN         NaN

# %% [markdown]
# # Step One: Drop Columns: Unnamed 2, 3, 4, 5 #

# %%
df.drop(columns='Unnamed: 2', inplace=True)

# %%
df.drop(columns='Unnamed: 3', inplace=True)

# %%
df.drop(columns='Unnamed: 4', inplace=True)

# %%
df.drop(columns='Unnamed: 5', inplace=True)

# %% [markdown]
# <i> Check your data frame: <i>

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                        Original Data Value
# 1                                                        NaN
# 2                                                 Series Id:
# 3                                              Series title:
# 4                                          Unadjusted series
# 5                                                     Union:
# 6                                                  Industry:
# 7                                                Occupation:
# 8                                                       Sex:
# 9                                                      Race:
# 10                                            Ethnic Origin:
# 11                                                      Age:
# 12                                                 Earnings:
# 13                                          Class of Worker:
# 14                                       Labor force status:
# 15                                                    Years:
# 16                                                       NaN
# 17                                                      Year
# 18                                                      2000
# 19                                                      2001
# 20                                                      2002
# 21                                                      2003
# 22                                                      2004
# 23                                                      2005
# 24                                                      2006
# 25                                                      2007
# 26                                                      2008
# 27                                                      2009
# 28                                                      2010
# 29                                                      2011
# 30                                                      2012
# 31                                                      2013
# 32                                                      2014
# 33                                                      2015
# 34                                                      2016
#
#                                                            Unnamed: 1
# 0                                                                 NaN
# 1                                                                 NaN
# 2                                                       LUU0204899701
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 4                                                                 NaN
# 5                                               Represented by unions
# 6                                                      All Industries
# 7                                                     All Occupations
# 8                                                          Both Sexes
# 9                                                           All Races
# 10                                                        All Origins
# 11                                                  16 years and over
# 12                                Person counts (number in thousands)
# 13      Wage and salary workers, excluding incorporated self employed
# 14                                                           Employed
# 15                                                       2000 to 2016
# 16                                                                NaN
# 17                                                             Annual
# 18                                                               10.5
# 19                                                               11.3
# 20                                                               10.6
# 21                                                                9.5
# 22                                                               11.5
# 23                                                               11.7
# 24                                                                 10
# 25                                                               10.6
# 26                                                               10.7
# 27                                                                 12
# 28                                                               11.2
# 29                                                               10.8
# 30                                                               10.5
# 31                                                               11.7
# 32                                                               12.1
# 33                                                                 11
# 34                                                                  9

# %% [markdown]
# # # Step Two: Create a new column 'Years' # #

# %%
df['Years'] = df['Union affiliation data from the Current Population Survey'][18:]

# %% [markdown]
# <i> Check your df <i>

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                        Original Data Value
# 1                                                        NaN
# 2                                                 Series Id:
# 3                                              Series title:
# 4                                          Unadjusted series
# 5                                                     Union:
# 6                                                  Industry:
# 7                                                Occupation:
# 8                                                       Sex:
# 9                                                      Race:
# 10                                            Ethnic Origin:
# 11                                                      Age:
# 12                                                 Earnings:
# 13                                          Class of Worker:
# 14                                       Labor force status:
# 15                                                    Years:
# 16                                                       NaN
# 17                                                      Year
# 18                                                      2000
# 19                                                      2001
# 20                                                      2002
# 21                                                      2003
# 22                                                      2004
# 23                                                      2005
# 24                                                      2006
# 25                                                      2007
# 26                                                      2008
# 27                                                      2009
# 28                                                      2010
# 29                                                      2011
# 30                                                      2012
# 31                                                      2013
# 32                                                      2014
# 33                                                      2015
# 34                                                      2016
#
#                                                            Unnamed: 1 Years
# 0                                                                 NaN   NaN
# 1                                                                 NaN   NaN
# 2                                                       LUU0204899701   NaN
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama   NaN
# 4                                                                 NaN   NaN
# 5                                               Represented by unions   NaN
# 6                                                      All Industries   NaN
# 7                                                     All Occupations   NaN
# 8                                                          Both Sexes   NaN
# 9                                                           All Races   NaN
# 10                                                        All Origins   NaN
# 11                                                  16 years and over   NaN
# 12                                Person counts (number in thousands)   NaN
# 13      Wage and salary workers, excluding incorporated self employed   NaN
# 14                                                           Employed   NaN
# 15                                                       2000 to 2016   NaN
# 16                                                                NaN   NaN
# 17                                                             Annual   NaN
# 18                                                               10.5  2000
# 19                                                               11.3  2001
# 20                                                               10.6  2002
# 21                                                                9.5  2003
# 22                                                               11.5  2004
# 23                                                               11.7  2005
# 24                                                                 10  2006
# 25                                                               10.6  2007
# 26                                                               10.7  2008
# 27                                                                 12  2009
# 28                                                               11.2  2010
# 29                                                               10.8  2011
# 30                                                               10.5  2012
# 31                                                               11.7  2013
# 32                                                               12.1  2014
# 33                                                                 11  2015
# 34                                                                  9  2016

# %% [markdown]
# # # Step Three: Create a new column 'Percent_Represented' # #

# %%
df['Percent_Represented'] = df['Unnamed: 1'][18:]

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                        Original Data Value
# 1                                                        NaN
# 2                                                 Series Id:
# 3                                              Series title:
# 4                                          Unadjusted series
# 5                                                     Union:
# 6                                                  Industry:
# 7                                                Occupation:
# 8                                                       Sex:
# 9                                                      Race:
# 10                                            Ethnic Origin:
# 11                                                      Age:
# 12                                                 Earnings:
# 13                                          Class of Worker:
# 14                                       Labor force status:
# 15                                                    Years:
# 16                                                       NaN
# 17                                                      Year
# 18                                                      2000
# 19                                                      2001
# 20                                                      2002
# 21                                                      2003
# 22                                                      2004
# 23                                                      2005
# 24                                                      2006
# 25                                                      2007
# 26                                                      2008
# 27                                                      2009
# 28                                                      2010
# 29                                                      2011
# 30                                                      2012
# 31                                                      2013
# 32                                                      2014
# 33                                                      2015
# 34                                                      2016
#
#                                                            Unnamed: 1 Years  \
# 0                                                                 NaN   NaN
# 1                                                                 NaN   NaN
# 2                                                       LUU0204899701   NaN
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama   NaN
# 4                                                                 NaN   NaN
# 5                                               Represented by unions   NaN
# 6                                                      All Industries   NaN
# 7                                                     All Occupations   NaN
# 8                                                          Both Sexes   NaN
# 9                                                           All Races   NaN
# 10                                                        All Origins   NaN
# 11                                                  16 years and over   NaN
# 12                                Person counts (number in thousands)   NaN
# 13      Wage and salary workers, excluding incorporated self employed   NaN
# 14                                                           Employed   NaN
# 15                                                       2000 to 2016   NaN
# 16                                                                NaN   NaN
# 17                                                             Annual   NaN
# 18                                                               10.5  2000
# 19                                                               11.3  2001
# 20                                                               10.6  2002
# 21                                                                9.5  2003
# 22                                                               11.5  2004
# 23                                                               11.7  2005
# 24                                                                 10  2006
# 25                                                               10.6  2007
# 26                                                               10.7  2008
# 27                                                                 12  2009
# 28                                                               11.2  2010
# 29                                                               10.8  2011
# 30                                                               10.5  2012
# 31                                                               11.7  2013
# 32                                                               12.1  2014
# 33                                                                 11  2015
# 34                                                                  9  2016
#
#    Percent_Represented
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                10.5
# 19                11.3
# 20                10.6
# 21                 9.5
# 22                11.5
# 23                11.7
# 24                  10
# 25                10.6
# 26                10.7
# 27                  12
# 28                11.2
# 29                10.8
# 30                10.5
# 31                11.7
# 32                12.1
# 33                  11
# 34                   9

# %% [markdown]
# # # Step Four: Create a value for "Series Title" # #

# %%
df['Series_Title'] = df['Unnamed: 1'][3]

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                        Original Data Value
# 1                                                        NaN
# 2                                                 Series Id:
# 3                                              Series title:
# 4                                          Unadjusted series
# 5                                                     Union:
# 6                                                  Industry:
# 7                                                Occupation:
# 8                                                       Sex:
# 9                                                      Race:
# 10                                            Ethnic Origin:
# 11                                                      Age:
# 12                                                 Earnings:
# 13                                          Class of Worker:
# 14                                       Labor force status:
# 15                                                    Years:
# 16                                                       NaN
# 17                                                      Year
# 18                                                      2000
# 19                                                      2001
# 20                                                      2002
# 21                                                      2003
# 22                                                      2004
# 23                                                      2005
# 24                                                      2006
# 25                                                      2007
# 26                                                      2008
# 27                                                      2009
# 28                                                      2010
# 29                                                      2011
# 30                                                      2012
# 31                                                      2013
# 32                                                      2014
# 33                                                      2015
# 34                                                      2016
#
#                                                            Unnamed: 1 Years  \
# 0                                                                 NaN   NaN
# 1                                                                 NaN   NaN
# 2                                                       LUU0204899701   NaN
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama   NaN
# 4                                                                 NaN   NaN
# 5                                               Represented by unions   NaN
# 6                                                      All Industries   NaN
# 7                                                     All Occupations   NaN
# 8                                                          Both Sexes   NaN
# 9                                                           All Races   NaN
# 10                                                        All Origins   NaN
# 11                                                  16 years and over   NaN
# 12                                Person counts (number in thousands)   NaN
# 13      Wage and salary workers, excluding incorporated self employed   NaN
# 14                                                           Employed   NaN
# 15                                                       2000 to 2016   NaN
# 16                                                                NaN   NaN
# 17                                                             Annual   NaN
# 18                                                               10.5  2000
# 19                                                               11.3  2001
# 20                                                               10.6  2002
# 21                                                                9.5  2003
# 22                                                               11.5  2004
# 23                                                               11.7  2005
# 24                                                                 10  2006
# 25                                                               10.6  2007
# 26                                                               10.7  2008
# 27                                                                 12  2009
# 28                                                               11.2  2010
# 29                                                               10.8  2011
# 30                                                               10.5  2012
# 31                                                               11.7  2013
# 32                                                               12.1  2014
# 33                                                                 11  2015
# 34                                                                  9  2016
#
#    Percent_Represented  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                10.5
# 19                11.3
# 20                10.6
# 21                 9.5
# 22                11.5
# 23                11.7
# 24                  10
# 25                10.6
# 26                10.7
# 27                  12
# 28                11.2
# 29                10.8
# 30                10.5
# 31                11.7
# 32                12.1
# 33                  11
# 34                   9
#
#                                                          Series_Title
# 0   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 1   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 4   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 5   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 6   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 7   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 8   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 9   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 10  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 11  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 12  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 13  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 14  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 15  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 16  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 17  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 18  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 19  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 20  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 21  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 22  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 23  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 24  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 25  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 26  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 27  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 28  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 29  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 30  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 31  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 32  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 33  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 34  (unadj)- Percent of employed, Represented by unions, (AL) Alabama

# %% [markdown]
# # # Step 5: Create a column for Union # #

# %%
df['Union'] = df['Unnamed: 1'][5]

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                        Original Data Value
# 1                                                        NaN
# 2                                                 Series Id:
# 3                                              Series title:
# 4                                          Unadjusted series
# 5                                                     Union:
# 6                                                  Industry:
# 7                                                Occupation:
# 8                                                       Sex:
# 9                                                      Race:
# 10                                            Ethnic Origin:
# 11                                                      Age:
# 12                                                 Earnings:
# 13                                          Class of Worker:
# 14                                       Labor force status:
# 15                                                    Years:
# 16                                                       NaN
# 17                                                      Year
# 18                                                      2000
# 19                                                      2001
# 20                                                      2002
# 21                                                      2003
# 22                                                      2004
# 23                                                      2005
# 24                                                      2006
# 25                                                      2007
# 26                                                      2008
# 27                                                      2009
# 28                                                      2010
# 29                                                      2011
# 30                                                      2012
# 31                                                      2013
# 32                                                      2014
# 33                                                      2015
# 34                                                      2016
#
#                                                            Unnamed: 1 Years  \
# 0                                                                 NaN   NaN
# 1                                                                 NaN   NaN
# 2                                                       LUU0204899701   NaN
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama   NaN
# 4                                                                 NaN   NaN
# 5                                               Represented by unions   NaN
# 6                                                      All Industries   NaN
# 7                                                     All Occupations   NaN
# 8                                                          Both Sexes   NaN
# 9                                                           All Races   NaN
# 10                                                        All Origins   NaN
# 11                                                  16 years and over   NaN
# 12                                Person counts (number in thousands)   NaN
# 13      Wage and salary workers, excluding incorporated self employed   NaN
# 14                                                           Employed   NaN
# 15                                                       2000 to 2016   NaN
# 16                                                                NaN   NaN
# 17                                                             Annual   NaN
# 18                                                               10.5  2000
# 19                                                               11.3  2001
# 20                                                               10.6  2002
# 21                                                                9.5  2003
# 22                                                               11.5  2004
# 23                                                               11.7  2005
# 24                                                                 10  2006
# 25                                                               10.6  2007
# 26                                                               10.7  2008
# 27                                                                 12  2009
# 28                                                               11.2  2010
# 29                                                               10.8  2011
# 30                                                               10.5  2012
# 31                                                               11.7  2013
# 32                                                               12.1  2014
# 33                                                                 11  2015
# 34                                                                  9  2016
#
#    Percent_Represented  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                10.5
# 19                11.3
# 20                10.6
# 21                 9.5
# 22                11.5
# 23                11.7
# 24                  10
# 25                10.6
# 26                10.7
# 27                  12
# 28                11.2
# 29                10.8
# 30                10.5
# 31                11.7
# 32                12.1
# 33                  11
# 34                   9
#
#                                                          Series_Title  \
# 0   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 1   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 4   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 5   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 6   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 7   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 8   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 9   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 10  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 11  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 12  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 13  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 14  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 15  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 16  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 17  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 18  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 19  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 20  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 21  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 22  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 23  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 24  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 25  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 26  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 27  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 28  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 29  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 30  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 31  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 32  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 33  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 34  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
#
#                     Union
# 0   Represented by unions
# 1   Represented by unions
# 2   Represented by unions
# 3   Represented by unions
# 4   Represented by unions
# 5   Represented by unions
# 6   Represented by unions
# 7   Represented by unions
# 8   Represented by unions
# 9   Represented by unions
# 10  Represented by unions
# 11  Represented by unions
# 12  Represented by unions
# 13  Represented by unions
# 14  Represented by unions
# 15  Represented by unions
# 16  Represented by unions
# 17  Represented by unions
# 18  Represented by unions
# 19  Represented by unions
# 20  Represented by unions
# 21  Represented by unions
# 22  Represented by unions
# 23  Represented by unions
# 24  Represented by unions
# 25  Represented by unions
# 26  Represented by unions
# 27  Represented by unions
# 28  Represented by unions
# 29  Represented by unions
# 30  Represented by unions
# 31  Represented by unions
# 32  Represented by unions
# 33  Represented by unions
# 34  Represented by unions

# %% [markdown]
# # # Step Six: Make a column for Industry # #

# %%
df['Industry'] = df['Unnamed: 1'][6]

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                        Original Data Value
# 1                                                        NaN
# 2                                                 Series Id:
# 3                                              Series title:
# 4                                          Unadjusted series
# 5                                                     Union:
# 6                                                  Industry:
# 7                                                Occupation:
# 8                                                       Sex:
# 9                                                      Race:
# 10                                            Ethnic Origin:
# 11                                                      Age:
# 12                                                 Earnings:
# 13                                          Class of Worker:
# 14                                       Labor force status:
# 15                                                    Years:
# 16                                                       NaN
# 17                                                      Year
# 18                                                      2000
# 19                                                      2001
# 20                                                      2002
# 21                                                      2003
# 22                                                      2004
# 23                                                      2005
# 24                                                      2006
# 25                                                      2007
# 26                                                      2008
# 27                                                      2009
# 28                                                      2010
# 29                                                      2011
# 30                                                      2012
# 31                                                      2013
# 32                                                      2014
# 33                                                      2015
# 34                                                      2016
#
#                                                            Unnamed: 1 Years  \
# 0                                                                 NaN   NaN
# 1                                                                 NaN   NaN
# 2                                                       LUU0204899701   NaN
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama   NaN
# 4                                                                 NaN   NaN
# 5                                               Represented by unions   NaN
# 6                                                      All Industries   NaN
# 7                                                     All Occupations   NaN
# 8                                                          Both Sexes   NaN
# 9                                                           All Races   NaN
# 10                                                        All Origins   NaN
# 11                                                  16 years and over   NaN
# 12                                Person counts (number in thousands)   NaN
# 13      Wage and salary workers, excluding incorporated self employed   NaN
# 14                                                           Employed   NaN
# 15                                                       2000 to 2016   NaN
# 16                                                                NaN   NaN
# 17                                                             Annual   NaN
# 18                                                               10.5  2000
# 19                                                               11.3  2001
# 20                                                               10.6  2002
# 21                                                                9.5  2003
# 22                                                               11.5  2004
# 23                                                               11.7  2005
# 24                                                                 10  2006
# 25                                                               10.6  2007
# 26                                                               10.7  2008
# 27                                                                 12  2009
# 28                                                               11.2  2010
# 29                                                               10.8  2011
# 30                                                               10.5  2012
# 31                                                               11.7  2013
# 32                                                               12.1  2014
# 33                                                                 11  2015
# 34                                                                  9  2016
#
#    Percent_Represented  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                10.5
# 19                11.3
# 20                10.6
# 21                 9.5
# 22                11.5
# 23                11.7
# 24                  10
# 25                10.6
# 26                10.7
# 27                  12
# 28                11.2
# 29                10.8
# 30                10.5
# 31                11.7
# 32                12.1
# 33                  11
# 34                   9
#
#                                                          Series_Title  \
# 0   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 1   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 4   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 5   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 6   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 7   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 8   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 9   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 10  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 11  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 12  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 13  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 14  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 15  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 16  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 17  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 18  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 19  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 20  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 21  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 22  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 23  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 24  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 25  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 26  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 27  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 28  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 29  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 30  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 31  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 32  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 33  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 34  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
#
#                     Union        Industry
# 0   Represented by unions  All Industries
# 1   Represented by unions  All Industries
# 2   Represented by unions  All Industries
# 3   Represented by unions  All Industries
# 4   Represented by unions  All Industries
# 5   Represented by unions  All Industries
# 6   Represented by unions  All Industries
# 7   Represented by unions  All Industries
# 8   Represented by unions  All Industries
# 9   Represented by unions  All Industries
# 10  Represented by unions  All Industries
# 11  Represented by unions  All Industries
# 12  Represented by unions  All Industries
# 13  Represented by unions  All Industries
# 14  Represented by unions  All Industries
# 15  Represented by unions  All Industries
# 16  Represented by unions  All Industries
# 17  Represented by unions  All Industries
# 18  Represented by unions  All Industries
# 19  Represented by unions  All Industries
# 20  Represented by unions  All Industries
# 21  Represented by unions  All Industries
# 22  Represented by unions  All Industries
# 23  Represented by unions  All Industries
# 24  Represented by unions  All Industries
# 25  Represented by unions  All Industries
# 26  Represented by unions  All Industries
# 27  Represented by unions  All Industries
# 28  Represented by unions  All Industries
# 29  Represented by unions  All Industries
# 30  Represented by unions  All Industries
# 31  Represented by unions  All Industries
# 32  Represented by unions  All Industries
# 33  Represented by unions  All Industries
# 34  Represented by unions  All Industries

# %% [markdown]
# # # Step Seven: Make a column for Earnings # #

# %%
df['Earnings'] = df['Unnamed: 1'][12]

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                        Original Data Value
# 1                                                        NaN
# 2                                                 Series Id:
# 3                                              Series title:
# 4                                          Unadjusted series
# 5                                                     Union:
# 6                                                  Industry:
# 7                                                Occupation:
# 8                                                       Sex:
# 9                                                      Race:
# 10                                            Ethnic Origin:
# 11                                                      Age:
# 12                                                 Earnings:
# 13                                          Class of Worker:
# 14                                       Labor force status:
# 15                                                    Years:
# 16                                                       NaN
# 17                                                      Year
# 18                                                      2000
# 19                                                      2001
# 20                                                      2002
# 21                                                      2003
# 22                                                      2004
# 23                                                      2005
# 24                                                      2006
# 25                                                      2007
# 26                                                      2008
# 27                                                      2009
# 28                                                      2010
# 29                                                      2011
# 30                                                      2012
# 31                                                      2013
# 32                                                      2014
# 33                                                      2015
# 34                                                      2016
#
#                                                            Unnamed: 1 Years  \
# 0                                                                 NaN   NaN
# 1                                                                 NaN   NaN
# 2                                                       LUU0204899701   NaN
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama   NaN
# 4                                                                 NaN   NaN
# 5                                               Represented by unions   NaN
# 6                                                      All Industries   NaN
# 7                                                     All Occupations   NaN
# 8                                                          Both Sexes   NaN
# 9                                                           All Races   NaN
# 10                                                        All Origins   NaN
# 11                                                  16 years and over   NaN
# 12                                Person counts (number in thousands)   NaN
# 13      Wage and salary workers, excluding incorporated self employed   NaN
# 14                                                           Employed   NaN
# 15                                                       2000 to 2016   NaN
# 16                                                                NaN   NaN
# 17                                                             Annual   NaN
# 18                                                               10.5  2000
# 19                                                               11.3  2001
# 20                                                               10.6  2002
# 21                                                                9.5  2003
# 22                                                               11.5  2004
# 23                                                               11.7  2005
# 24                                                                 10  2006
# 25                                                               10.6  2007
# 26                                                               10.7  2008
# 27                                                                 12  2009
# 28                                                               11.2  2010
# 29                                                               10.8  2011
# 30                                                               10.5  2012
# 31                                                               11.7  2013
# 32                                                               12.1  2014
# 33                                                                 11  2015
# 34                                                                  9  2016
#
#    Percent_Represented  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                10.5
# 19                11.3
# 20                10.6
# 21                 9.5
# 22                11.5
# 23                11.7
# 24                  10
# 25                10.6
# 26                10.7
# 27                  12
# 28                11.2
# 29                10.8
# 30                10.5
# 31                11.7
# 32                12.1
# 33                  11
# 34                   9
#
#                                                          Series_Title  \
# 0   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 1   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 4   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 5   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 6   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 7   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 8   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 9   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 10  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 11  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 12  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 13  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 14  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 15  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 16  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 17  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 18  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 19  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 20  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 21  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 22  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 23  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 24  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 25  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 26  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 27  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 28  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 29  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 30  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 31  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 32  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 33  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 34  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
#
#                     Union        Industry                             Earnings
# 0   Represented by unions  All Industries  Person counts (number in thousands)
# 1   Represented by unions  All Industries  Person counts (number in thousands)
# 2   Represented by unions  All Industries  Person counts (number in thousands)
# 3   Represented by unions  All Industries  Person counts (number in thousands)
# 4   Represented by unions  All Industries  Person counts (number in thousands)
# 5   Represented by unions  All Industries  Person counts (number in thousands)
# 6   Represented by unions  All Industries  Person counts (number in thousands)
# 7   Represented by unions  All Industries  Person counts (number in thousands)
# 8   Represented by unions  All Industries  Person counts (number in thousands)
# 9   Represented by unions  All Industries  Person counts (number in thousands)
# 10  Represented by unions  All Industries  Person counts (number in thousands)
# 11  Represented by unions  All Industries  Person counts (number in thousands)
# 12  Represented by unions  All Industries  Person counts (number in thousands)
# 13  Represented by unions  All Industries  Person counts (number in thousands)
# 14  Represented by unions  All Industries  Person counts (number in thousands)
# 15  Represented by unions  All Industries  Person counts (number in thousands)
# 16  Represented by unions  All Industries  Person counts (number in thousands)
# 17  Represented by unions  All Industries  Person counts (number in thousands)
# 18  Represented by unions  All Industries  Person counts (number in thousands)
# 19  Represented by unions  All Industries  Person counts (number in thousands)
# 20  Represented by unions  All Industries  Person counts (number in thousands)
# 21  Represented by unions  All Industries  Person counts (number in thousands)
# 22  Represented by unions  All Industries  Person counts (number in thousands)
# 23  Represented by unions  All Industries  Person counts (number in thousands)
# 24  Represented by unions  All Industries  Person counts (number in thousands)
# 25  Represented by unions  All Industries  Person counts (number in thousands)
# 26  Represented by unions  All Industries  Person counts (number in thousands)
# 27  Represented by unions  All Industries  Person counts (number in thousands)
# 28  Represented by unions  All Industries  Person counts (number in thousands)
# 29  Represented by unions  All Industries  Person counts (number in thousands)
# 30  Represented by unions  All Industries  Person counts (number in thousands)
# 31  Represented by unions  All Industries  Person counts (number in thousands)
# 32  Represented by unions  All Industries  Person counts (number in thousands)
# 33  Represented by unions  All Industries  Person counts (number in thousands)
# 34  Represented by unions  All Industries  Person counts (number in thousands)

# %% [markdown]
# # # Step Eight: Make a column for Class of Workers # #

# %%
df['Class_of_Worker'] = df['Unnamed: 1'][13]

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                        Original Data Value
# 1                                                        NaN
# 2                                                 Series Id:
# 3                                              Series title:
# 4                                          Unadjusted series
# 5                                                     Union:
# 6                                                  Industry:
# 7                                                Occupation:
# 8                                                       Sex:
# 9                                                      Race:
# 10                                            Ethnic Origin:
# 11                                                      Age:
# 12                                                 Earnings:
# 13                                          Class of Worker:
# 14                                       Labor force status:
# 15                                                    Years:
# 16                                                       NaN
# 17                                                      Year
# 18                                                      2000
# 19                                                      2001
# 20                                                      2002
# 21                                                      2003
# 22                                                      2004
# 23                                                      2005
# 24                                                      2006
# 25                                                      2007
# 26                                                      2008
# 27                                                      2009
# 28                                                      2010
# 29                                                      2011
# 30                                                      2012
# 31                                                      2013
# 32                                                      2014
# 33                                                      2015
# 34                                                      2016
#
#                                                            Unnamed: 1 Years  \
# 0                                                                 NaN   NaN
# 1                                                                 NaN   NaN
# 2                                                       LUU0204899701   NaN
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama   NaN
# 4                                                                 NaN   NaN
# 5                                               Represented by unions   NaN
# 6                                                      All Industries   NaN
# 7                                                     All Occupations   NaN
# 8                                                          Both Sexes   NaN
# 9                                                           All Races   NaN
# 10                                                        All Origins   NaN
# 11                                                  16 years and over   NaN
# 12                                Person counts (number in thousands)   NaN
# 13      Wage and salary workers, excluding incorporated self employed   NaN
# 14                                                           Employed   NaN
# 15                                                       2000 to 2016   NaN
# 16                                                                NaN   NaN
# 17                                                             Annual   NaN
# 18                                                               10.5  2000
# 19                                                               11.3  2001
# 20                                                               10.6  2002
# 21                                                                9.5  2003
# 22                                                               11.5  2004
# 23                                                               11.7  2005
# 24                                                                 10  2006
# 25                                                               10.6  2007
# 26                                                               10.7  2008
# 27                                                                 12  2009
# 28                                                               11.2  2010
# 29                                                               10.8  2011
# 30                                                               10.5  2012
# 31                                                               11.7  2013
# 32                                                               12.1  2014
# 33                                                                 11  2015
# 34                                                                  9  2016
#
#    Percent_Represented  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                10.5
# 19                11.3
# 20                10.6
# 21                 9.5
# 22                11.5
# 23                11.7
# 24                  10
# 25                10.6
# 26                10.7
# 27                  12
# 28                11.2
# 29                10.8
# 30                10.5
# 31                11.7
# 32                12.1
# 33                  11
# 34                   9
#
#                                                          Series_Title  \
# 0   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 1   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 3   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 4   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 5   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 6   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 7   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 8   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 9   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 10  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 11  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 12  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 13  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 14  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 15  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 16  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 17  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 18  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 19  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 20  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 21  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 22  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 23  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 24  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 25  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 26  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 27  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 28  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 29  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 30  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 31  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 32  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 33  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 34  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
#
#                     Union        Industry  \
# 0   Represented by unions  All Industries
# 1   Represented by unions  All Industries
# 2   Represented by unions  All Industries
# 3   Represented by unions  All Industries
# 4   Represented by unions  All Industries
# 5   Represented by unions  All Industries
# 6   Represented by unions  All Industries
# 7   Represented by unions  All Industries
# 8   Represented by unions  All Industries
# 9   Represented by unions  All Industries
# 10  Represented by unions  All Industries
# 11  Represented by unions  All Industries
# 12  Represented by unions  All Industries
# 13  Represented by unions  All Industries
# 14  Represented by unions  All Industries
# 15  Represented by unions  All Industries
# 16  Represented by unions  All Industries
# 17  Represented by unions  All Industries
# 18  Represented by unions  All Industries
# 19  Represented by unions  All Industries
# 20  Represented by unions  All Industries
# 21  Represented by unions  All Industries
# 22  Represented by unions  All Industries
# 23  Represented by unions  All Industries
# 24  Represented by unions  All Industries
# 25  Represented by unions  All Industries
# 26  Represented by unions  All Industries
# 27  Represented by unions  All Industries
# 28  Represented by unions  All Industries
# 29  Represented by unions  All Industries
# 30  Represented by unions  All Industries
# 31  Represented by unions  All Industries
# 32  Represented by unions  All Industries
# 33  Represented by unions  All Industries
# 34  Represented by unions  All Industries
#
#                                Earnings  \
# 0   Person counts (number in thousands)
# 1   Person counts (number in thousands)
# 2   Person counts (number in thousands)
# 3   Person counts (number in thousands)
# 4   Person counts (number in thousands)
# 5   Person counts (number in thousands)
# 6   Person counts (number in thousands)
# 7   Person counts (number in thousands)
# 8   Person counts (number in thousands)
# 9   Person counts (number in thousands)
# 10  Person counts (number in thousands)
# 11  Person counts (number in thousands)
# 12  Person counts (number in thousands)
# 13  Person counts (number in thousands)
# 14  Person counts (number in thousands)
# 15  Person counts (number in thousands)
# 16  Person counts (number in thousands)
# 17  Person counts (number in thousands)
# 18  Person counts (number in thousands)
# 19  Person counts (number in thousands)
# 20  Person counts (number in thousands)
# 21  Person counts (number in thousands)
# 22  Person counts (number in thousands)
# 23  Person counts (number in thousands)
# 24  Person counts (number in thousands)
# 25  Person counts (number in thousands)
# 26  Person counts (number in thousands)
# 27  Person counts (number in thousands)
# 28  Person counts (number in thousands)
# 29  Person counts (number in thousands)
# 30  Person counts (number in thousands)
# 31  Person counts (number in thousands)
# 32  Person counts (number in thousands)
# 33  Person counts (number in thousands)
# 34  Person counts (number in thousands)
#
#                                                   Class_of_Worker
# 0   Wage and salary workers, excluding incorporated self employed
# 1   Wage and salary workers, excluding incorporated self employed
# 2   Wage and salary workers, excluding incorporated self employed
# 3   Wage and salary workers, excluding incorporated self employed
# 4   Wage and salary workers, excluding incorporated self employed
# 5   Wage and salary workers, excluding incorporated self employed
# 6   Wage and salary workers, excluding incorporated self employed
# 7   Wage and salary workers, excluding incorporated self employed
# 8   Wage and salary workers, excluding incorporated self employed
# 9   Wage and salary workers, excluding incorporated self employed
# 10  Wage and salary workers, excluding incorporated self employed
# 11  Wage and salary workers, excluding incorporated self employed
# 12  Wage and salary workers, excluding incorporated self employed
# 13  Wage and salary workers, excluding incorporated self employed
# 14  Wage and salary workers, excluding incorporated self employed
# 15  Wage and salary workers, excluding incorporated self employed
# 16  Wage and salary workers, excluding incorporated self employed
# 17  Wage and salary workers, excluding incorporated self employed
# 18  Wage and salary workers, excluding incorporated self employed
# 19  Wage and salary workers, excluding incorporated self employed
# 20  Wage and salary workers, excluding incorporated self employed
# 21  Wage and salary workers, excluding incorporated self employed
# 22  Wage and salary workers, excluding incorporated self employed
# 23  Wage and salary workers, excluding incorporated self employed
# 24  Wage and salary workers, excluding incorporated self employed
# 25  Wage and salary workers, excluding incorporated self employed
# 26  Wage and salary workers, excluding incorporated self employed
# 27  Wage and salary workers, excluding incorporated self employed
# 28  Wage and salary workers, excluding incorporated self employed
# 29  Wage and salary workers, excluding incorporated self employed
# 30  Wage and salary workers, excluding incorporated self employed
# 31  Wage and salary workers, excluding incorporated self employed
# 32  Wage and salary workers, excluding incorporated self employed
# 33  Wage and salary workers, excluding incorporated self employed
# 34  Wage and salary workers, excluding incorporated self employed

# %% [markdown]
# # # Step Eight: This seems good, but get rid of the NaN values and narrow down your rows  # #

# %%
df = df.iloc[18:]

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey Unnamed: 1 Years  \
# 18                                                      2000       10.5  2000
# 19                                                      2001       11.3  2001
# 20                                                      2002       10.6  2002
# 21                                                      2003        9.5  2003
# 22                                                      2004       11.5  2004
# 23                                                      2005       11.7  2005
# 24                                                      2006         10  2006
# 25                                                      2007       10.6  2007
# 26                                                      2008       10.7  2008
# 27                                                      2009         12  2009
# 28                                                      2010       11.2  2010
# 29                                                      2011       10.8  2011
# 30                                                      2012       10.5  2012
# 31                                                      2013       11.7  2013
# 32                                                      2014       12.1  2014
# 33                                                      2015         11  2015
# 34                                                      2016          9  2016
#
#    Percent_Represented  \
# 18                10.5
# 19                11.3
# 20                10.6
# 21                 9.5
# 22                11.5
# 23                11.7
# 24                  10
# 25                10.6
# 26                10.7
# 27                  12
# 28                11.2
# 29                10.8
# 30                10.5
# 31                11.7
# 32                12.1
# 33                  11
# 34                   9
#
#                                                          Series_Title  \
# 18  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 19  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 20  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 21  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 22  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 23  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 24  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 25  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 26  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 27  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 28  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 29  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 30  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 31  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 32  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 33  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 34  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
#
#                     Union        Industry  \
# 18  Represented by unions  All Industries
# 19  Represented by unions  All Industries
# 20  Represented by unions  All Industries
# 21  Represented by unions  All Industries
# 22  Represented by unions  All Industries
# 23  Represented by unions  All Industries
# 24  Represented by unions  All Industries
# 25  Represented by unions  All Industries
# 26  Represented by unions  All Industries
# 27  Represented by unions  All Industries
# 28  Represented by unions  All Industries
# 29  Represented by unions  All Industries
# 30  Represented by unions  All Industries
# 31  Represented by unions  All Industries
# 32  Represented by unions  All Industries
# 33  Represented by unions  All Industries
# 34  Represented by unions  All Industries
#
#                                Earnings  \
# 18  Person counts (number in thousands)
# 19  Person counts (number in thousands)
# 20  Person counts (number in thousands)
# 21  Person counts (number in thousands)
# 22  Person counts (number in thousands)
# 23  Person counts (number in thousands)
# 24  Person counts (number in thousands)
# 25  Person counts (number in thousands)
# 26  Person counts (number in thousands)
# 27  Person counts (number in thousands)
# 28  Person counts (number in thousands)
# 29  Person counts (number in thousands)
# 30  Person counts (number in thousands)
# 31  Person counts (number in thousands)
# 32  Person counts (number in thousands)
# 33  Person counts (number in thousands)
# 34  Person counts (number in thousands)
#
#                                                   Class_of_Worker
# 18  Wage and salary workers, excluding incorporated self employed
# 19  Wage and salary workers, excluding incorporated self employed
# 20  Wage and salary workers, excluding incorporated self employed
# 21  Wage and salary workers, excluding incorporated self employed
# 22  Wage and salary workers, excluding incorporated self employed
# 23  Wage and salary workers, excluding incorporated self employed
# 24  Wage and salary workers, excluding incorporated self employed
# 25  Wage and salary workers, excluding incorporated self employed
# 26  Wage and salary workers, excluding incorporated self employed
# 27  Wage and salary workers, excluding incorporated self employed
# 28  Wage and salary workers, excluding incorporated self employed
# 29  Wage and salary workers, excluding incorporated self employed
# 30  Wage and salary workers, excluding incorporated self employed
# 31  Wage and salary workers, excluding incorporated self employed
# 32  Wage and salary workers, excluding incorporated self employed
# 33  Wage and salary workers, excluding incorporated self employed
# 34  Wage and salary workers, excluding incorporated self employed

# %% [markdown]
# # # Step Nine: You can also drop those columns Union Affliation Data and Unnamed 1 Now. We got what we needed # #

# %%
df.drop(columns="Union affiliation data from the Current Population Survey" , inplace=True)
# Out:
# /Users/TekendraMBP/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df.drop(columns='Unnamed: 1' , inplace=True)
# Out:
# /Users/TekendraMBP/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df
# Out:
#    Years Percent_Represented  \
# 18  2000                10.5
# 19  2001                11.3
# 20  2002                10.6
# 21  2003                 9.5
# 22  2004                11.5
# 23  2005                11.7
# 24  2006                  10
# 25  2007                10.6
# 26  2008                10.7
# 27  2009                  12
# 28  2010                11.2
# 29  2011                10.8
# 30  2012                10.5
# 31  2013                11.7
# 32  2014                12.1
# 33  2015                  11
# 34  2016                   9
#
#                                                          Series_Title  \
# 18  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 19  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 20  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 21  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 22  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 23  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 24  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 25  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 26  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 27  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 28  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 29  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 30  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 31  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 32  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 33  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 34  (unadj)- Percent of employed, Represented by unions, (AL) Alabama
#
#                     Union        Industry  \
# 18  Represented by unions  All Industries
# 19  Represented by unions  All Industries
# 20  Represented by unions  All Industries
# 21  Represented by unions  All Industries
# 22  Represented by unions  All Industries
# 23  Represented by unions  All Industries
# 24  Represented by unions  All Industries
# 25  Represented by unions  All Industries
# 26  Represented by unions  All Industries
# 27  Represented by unions  All Industries
# 28  Represented by unions  All Industries
# 29  Represented by unions  All Industries
# 30  Represented by unions  All Industries
# 31  Represented by unions  All Industries
# 32  Represented by unions  All Industries
# 33  Represented by unions  All Industries
# 34  Represented by unions  All Industries
#
#                                Earnings  \
# 18  Person counts (number in thousands)
# 19  Person counts (number in thousands)
# 20  Person counts (number in thousands)
# 21  Person counts (number in thousands)
# 22  Person counts (number in thousands)
# 23  Person counts (number in thousands)
# 24  Person counts (number in thousands)
# 25  Person counts (number in thousands)
# 26  Person counts (number in thousands)
# 27  Person counts (number in thousands)
# 28  Person counts (number in thousands)
# 29  Person counts (number in thousands)
# 30  Person counts (number in thousands)
# 31  Person counts (number in thousands)
# 32  Person counts (number in thousands)
# 33  Person counts (number in thousands)
# 34  Person counts (number in thousands)
#
#                                                   Class_of_Worker
# 18  Wage and salary workers, excluding incorporated self employed
# 19  Wage and salary workers, excluding incorporated self employed
# 20  Wage and salary workers, excluding incorporated self employed
# 21  Wage and salary workers, excluding incorporated self employed
# 22  Wage and salary workers, excluding incorporated self employed
# 23  Wage and salary workers, excluding incorporated self employed
# 24  Wage and salary workers, excluding incorporated self employed
# 25  Wage and salary workers, excluding incorporated self employed
# 26  Wage and salary workers, excluding incorporated self employed
# 27  Wage and salary workers, excluding incorporated self employed
# 28  Wage and salary workers, excluding incorporated self employed
# 29  Wage and salary workers, excluding incorporated self employed
# 30  Wage and salary workers, excluding incorporated self employed
# 31  Wage and salary workers, excluding incorporated self employed
# 32  Wage and salary workers, excluding incorporated self employed
# 33  Wage and salary workers, excluding incorporated self employed
# 34  Wage and salary workers, excluding incorporated self employed

# %% [markdown]
# # # Step Ten: Wouldn't it be nice if our Index matched our years? Why dont we make that a thing? # #

# %%
df.set_index('Years', drop=True, append=False, inplace=True, verify_integrity=False)

# %%
df
# Out:
#       Percent_Represented  \
# Years
# 2000                 10.5
# 2001                 11.3
# 2002                 10.6
# 2003                  9.5
# 2004                 11.5
# 2005                 11.7
# 2006                   10
# 2007                 10.6
# 2008                 10.7
# 2009                   12
# 2010                 11.2
# 2011                 10.8
# 2012                 10.5
# 2013                 11.7
# 2014                 12.1
# 2015                   11
# 2016                    9
#
#                                                             Series_Title  \
# Years
# 2000   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2001   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2002   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2003   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2004   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2005   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2006   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2007   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2008   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2009   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2010   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2011   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2012   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2013   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2014   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2015   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2016   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
#
#                        Union        Industry  \
# Years
# 2000   Represented by unions  All Industries
# 2001   Represented by unions  All Industries
# 2002   Represented by unions  All Industries
# 2003   Represented by unions  All Industries
# 2004   Represented by unions  All Industries
# 2005   Represented by unions  All Industries
# 2006   Represented by unions  All Industries
# 2007   Represented by unions  All Industries
# 2008   Represented by unions  All Industries
# 2009   Represented by unions  All Industries
# 2010   Represented by unions  All Industries
# 2011   Represented by unions  All Industries
# 2012   Represented by unions  All Industries
# 2013   Represented by unions  All Industries
# 2014   Represented by unions  All Industries
# 2015   Represented by unions  All Industries
# 2016   Represented by unions  All Industries
#
#                                   Earnings  \
# Years
# 2000   Person counts (number in thousands)
# 2001   Person counts (number in thousands)
# 2002   Person counts (number in thousands)
# 2003   Person counts (number in thousands)
# 2004   Person counts (number in thousands)
# 2005   Person counts (number in thousands)
# 2006   Person counts (number in thousands)
# 2007   Person counts (number in thousands)
# 2008   Person counts (number in thousands)
# 2009   Person counts (number in thousands)
# 2010   Person counts (number in thousands)
# 2011   Person counts (number in thousands)
# 2012   Person counts (number in thousands)
# 2013   Person counts (number in thousands)
# 2014   Person counts (number in thousands)
# 2015   Person counts (number in thousands)
# 2016   Person counts (number in thousands)
#
#                                                      Class_of_Worker
# Years
# 2000   Wage and salary workers, excluding incorporated self employed
# 2001   Wage and salary workers, excluding incorporated self employed
# 2002   Wage and salary workers, excluding incorporated self employed
# 2003   Wage and salary workers, excluding incorporated self employed
# 2004   Wage and salary workers, excluding incorporated self employed
# 2005   Wage and salary workers, excluding incorporated self employed
# 2006   Wage and salary workers, excluding incorporated self employed
# 2007   Wage and salary workers, excluding incorporated self employed
# 2008   Wage and salary workers, excluding incorporated self employed
# 2009   Wage and salary workers, excluding incorporated self employed
# 2010   Wage and salary workers, excluding incorporated self employed
# 2011   Wage and salary workers, excluding incorporated self employed
# 2012   Wage and salary workers, excluding incorporated self employed
# 2013   Wage and salary workers, excluding incorporated self employed
# 2014   Wage and salary workers, excluding incorporated self employed
# 2015   Wage and salary workers, excluding incorporated self employed
# 2016   Wage and salary workers, excluding incorporated self employed

# %% [markdown]
# # Step Eleven: Eventually we're going to need to geocode. Let's get the State's Acronymn in one column and State Name in another column. Be careful and make sure this step can work on several different states.
#
#
#
#
# # Name the State's acronymn "STUSPS"
#
# # Name the State's name "State"

# %%
df['STUSPS'] = df['Series_Title'].str.extract(r' \((\w\w)\)')
# Out:
# /Users/TekendraMBP/.pyenv/versions/3.6.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#       Percent_Represented  \
# Years
# 2000                 10.5
# 2001                 11.3
# 2002                 10.6
# 2003                  9.5
# 2004                 11.5
# 2005                 11.7
# 2006                   10
# 2007                 10.6
# 2008                 10.7
# 2009                   12
# 2010                 11.2
# 2011                 10.8
# 2012                 10.5
# 2013                 11.7
# 2014                 12.1
# 2015                   11
# 2016                    9
#
#                                                             Series_Title  \
# Years
# 2000   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2001   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2002   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2003   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2004   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2005   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2006   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2007   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2008   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2009   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2010   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2011   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2012   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2013   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2014   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2015   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2016   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
#
#                        Union        Industry  \
# Years
# 2000   Represented by unions  All Industries
# 2001   Represented by unions  All Industries
# 2002   Represented by unions  All Industries
# 2003   Represented by unions  All Industries
# 2004   Represented by unions  All Industries
# 2005   Represented by unions  All Industries
# 2006   Represented by unions  All Industries
# 2007   Represented by unions  All Industries
# 2008   Represented by unions  All Industries
# 2009   Represented by unions  All Industries
# 2010   Represented by unions  All Industries
# 2011   Represented by unions  All Industries
# 2012   Represented by unions  All Industries
# 2013   Represented by unions  All Industries
# 2014   Represented by unions  All Industries
# 2015   Represented by unions  All Industries
# 2016   Represented by unions  All Industries
#
#                                   Earnings  \
# Years
# 2000   Person counts (number in thousands)
# 2001   Person counts (number in thousands)
# 2002   Person counts (number in thousands)
# 2003   Person counts (number in thousands)
# 2004   Person counts (number in thousands)
# 2005   Person counts (number in thousands)
# 2006   Person counts (number in thousands)
# 2007   Person counts (number in thousands)
# 2008   Person counts (number in thousands)
# 2009   Person counts (number in thousands)
# 2010   Person counts (number in thousands)
# 2011   Person counts (number in thousands)
# 2012   Person counts (number in thousands)
# 2013   Person counts (number in thousands)
# 2014   Person counts (number in thousands)
# 2015   Person counts (number in thousands)
# 2016   Person counts (number in thousands)
#
#                                                      Class_of_Worker STUSPS
# Years
# 2000   Wage and salary workers, excluding incorporated self employed     AL
# 2001   Wage and salary workers, excluding incorporated self employed     AL
# 2002   Wage and salary workers, excluding incorporated self employed     AL
# 2003   Wage and salary workers, excluding incorporated self employed     AL
# 2004   Wage and salary workers, excluding incorporated self employed     AL
# 2005   Wage and salary workers, excluding incorporated self employed     AL
# 2006   Wage and salary workers, excluding incorporated self employed     AL
# 2007   Wage and salary workers, excluding incorporated self employed     AL
# 2008   Wage and salary workers, excluding incorporated self employed     AL
# 2009   Wage and salary workers, excluding incorporated self employed     AL
# 2010   Wage and salary workers, excluding incorporated self employed     AL
# 2011   Wage and salary workers, excluding incorporated self employed     AL
# 2012   Wage and salary workers, excluding incorporated self employed     AL
# 2013   Wage and salary workers, excluding incorporated self employed     AL
# 2014   Wage and salary workers, excluding incorporated self employed     AL
# 2015   Wage and salary workers, excluding incorporated self employed     AL
# 2016   Wage and salary workers, excluding incorporated self employed     AL

# %%
df['State'] = df['Series_Title'].str.extract(r'\(\w\w\)(.*)')
# Out:
# /Users/TekendraMBP/.pyenv/versions/3.6.4/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#       Percent_Represented  \
# Years
# 2000                 10.5
# 2001                 11.3
# 2002                 10.6
# 2003                  9.5
# 2004                 11.5
# 2005                 11.7
# 2006                   10
# 2007                 10.6
# 2008                 10.7
# 2009                   12
# 2010                 11.2
# 2011                 10.8
# 2012                 10.5
# 2013                 11.7
# 2014                 12.1
# 2015                   11
# 2016                    9
#
#                                                             Series_Title  \
# Years
# 2000   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2001   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2002   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2003   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2004   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2005   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2006   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2007   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2008   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2009   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2010   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2011   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2012   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2013   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2014   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2015   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
# 2016   (unadj)- Percent of employed, Represented by unions, (AL) Alabama
#
#                        Union        Industry  \
# Years
# 2000   Represented by unions  All Industries
# 2001   Represented by unions  All Industries
# 2002   Represented by unions  All Industries
# 2003   Represented by unions  All Industries
# 2004   Represented by unions  All Industries
# 2005   Represented by unions  All Industries
# 2006   Represented by unions  All Industries
# 2007   Represented by unions  All Industries
# 2008   Represented by unions  All Industries
# 2009   Represented by unions  All Industries
# 2010   Represented by unions  All Industries
# 2011   Represented by unions  All Industries
# 2012   Represented by unions  All Industries
# 2013   Represented by unions  All Industries
# 2014   Represented by unions  All Industries
# 2015   Represented by unions  All Industries
# 2016   Represented by unions  All Industries
#
#                                   Earnings  \
# Years
# 2000   Person counts (number in thousands)
# 2001   Person counts (number in thousands)
# 2002   Person counts (number in thousands)
# 2003   Person counts (number in thousands)
# 2004   Person counts (number in thousands)
# 2005   Person counts (number in thousands)
# 2006   Person counts (number in thousands)
# 2007   Person counts (number in thousands)
# 2008   Person counts (number in thousands)
# 2009   Person counts (number in thousands)
# 2010   Person counts (number in thousands)
# 2011   Person counts (number in thousands)
# 2012   Person counts (number in thousands)
# 2013   Person counts (number in thousands)
# 2014   Person counts (number in thousands)
# 2015   Person counts (number in thousands)
# 2016   Person counts (number in thousands)
#
#                                                      Class_of_Worker STUSPS  \
# Years
# 2000   Wage and salary workers, excluding incorporated self employed     AL
# 2001   Wage and salary workers, excluding incorporated self employed     AL
# 2002   Wage and salary workers, excluding incorporated self employed     AL
# 2003   Wage and salary workers, excluding incorporated self employed     AL
# 2004   Wage and salary workers, excluding incorporated self employed     AL
# 2005   Wage and salary workers, excluding incorporated self employed     AL
# 2006   Wage and salary workers, excluding incorporated self employed     AL
# 2007   Wage and salary workers, excluding incorporated self employed     AL
# 2008   Wage and salary workers, excluding incorporated self employed     AL
# 2009   Wage and salary workers, excluding incorporated self employed     AL
# 2010   Wage and salary workers, excluding incorporated self employed     AL
# 2011   Wage and salary workers, excluding incorporated self employed     AL
# 2012   Wage and salary workers, excluding incorporated self employed     AL
# 2013   Wage and salary workers, excluding incorporated self employed     AL
# 2014   Wage and salary workers, excluding incorporated self employed     AL
# 2015   Wage and salary workers, excluding incorporated self employed     AL
# 2016   Wage and salary workers, excluding incorporated self employed     AL
#
#           State
# Years
# 2000    Alabama
# 2001    Alabama
# 2002    Alabama
# 2003    Alabama
# 2004    Alabama
# 2005    Alabama
# 2006    Alabama
# 2007    Alabama
# 2008    Alabama
# 2009    Alabama
# 2010    Alabama
# 2011    Alabama
# 2012    Alabama
# 2013    Alabama
# 2014    Alabama
# 2015    Alabama
# 2016    Alabama

# %%
# # Step Twelve: Great Job! Let's save this as a CSV and make anew ipynb where I right a function to do this

# %%
state = df.at[2000, 'State'].strip()

# %%
df.to_csv(state + "_Represented_by_Union.csv" , index=False)
