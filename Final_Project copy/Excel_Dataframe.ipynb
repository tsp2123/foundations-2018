# %%
import pandas as pd

# %%
Employed_Wage_Salary_Workers = pd.ExcelFile('/Users/TekendraMBP/Documents/Lede_Program/Databases/Final_Project/Unionization_Data/SeriesReport-20180628142209_7c4567.xlsx')

# %%
Employed_Wage_Salary_Workers.sheet_names
# Out:
# ['BLS Data Series']

# %%
df = Employed_Wage_Salary_Workers.parse('BLS Data Series')

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                 Original Data Value
# 1                                                 NaN
# 2                                          Series Id:
# 3                                       Series title:
# 4                                   Unadjusted series
# 5                                              Union:
# 6                                           Industry:
# 7                                         Occupation:
# 8                                                Sex:
# 9                                               Race:
# 10                                     Ethnic Origin:
# 11                                               Age:
# 12                                          Earnings:
# 13                                   Class of Worker:
# 14                                Labor force status:
# 15                                             Years:
# ...

# %%
df.drop(columns='Unnamed: 2', inplace=True)

# %%
df.drop(columns='Unnamed: 3', inplace=True)

# %%
df.drop(columns='Unnamed: 4', inplace=True)

# %%
df.drop(columns='Unnamed: 5', inplace=True)

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                 Original Data Value
# 1                                                 NaN
# 2                                          Series Id:
# 3                                       Series title:
# 4                                   Unadjusted series
# 5                                              Union:
# 6                                           Industry:
# 7                                         Occupation:
# 8                                                Sex:
# 9                                               Race:
# 10                                     Ethnic Origin:
# 11                                               Age:
# 12                                          Earnings:
# 13                                   Class of Worker:
# 14                                Labor force status:
# 15                                             Years:
# ...

# %%
df['Years'] = df['Union affiliation data from the Current Population Survey'][18:]

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                 Original Data Value
# 1                                                 NaN
# 2                                          Series Id:
# 3                                       Series title:
# 4                                   Unadjusted series
# 5                                              Union:
# 6                                           Industry:
# 7                                         Occupation:
# 8                                                Sex:
# 9                                               Race:
# 10                                     Ethnic Origin:
# 11                                               Age:
# 12                                          Earnings:
# 13                                   Class of Worker:
# 14                                Labor force status:
# 15                                             Years:
# ...

# %%
df['Labor_Force_in_Thousands'] = df['Unnamed: 1'][18:]

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                 Original Data Value
# 1                                                 NaN
# 2                                          Series Id:
# 3                                       Series title:
# 4                                   Unadjusted series
# 5                                              Union:
# 6                                           Industry:
# 7                                         Occupation:
# 8                                                Sex:
# 9                                               Race:
# 10                                     Ethnic Origin:
# 11                                               Age:
# 12                                          Earnings:
# 13                                   Class of Worker:
# 14                                Labor force status:
# 15                                             Years:
# ...

# %%
df['Series_Title'] = df['Unnamed: 1'][3]

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                 Original Data Value
# 1                                                 NaN
# 2                                          Series Id:
# 3                                       Series title:
# 4                                   Unadjusted series
# 5                                              Union:
# 6                                           Industry:
# 7                                         Occupation:
# 8                                                Sex:
# 9                                               Race:
# 10                                     Ethnic Origin:
# 11                                               Age:
# 12                                          Earnings:
# 13                                   Class of Worker:
# 14                                Labor force status:
# 15                                             Years:
# ...

# %%
df['Class_of_Worker'] = df['Unnamed: 1'][13]

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                 Original Data Value
# 1                                                 NaN
# 2                                          Series Id:
# 3                                       Series title:
# 4                                   Unadjusted series
# 5                                              Union:
# 6                                           Industry:
# 7                                         Occupation:
# 8                                                Sex:
# 9                                               Race:
# 10                                     Ethnic Origin:
# 11                                               Age:
# 12                                          Earnings:
# 13                                   Class of Worker:
# 14                                Labor force status:
# 15                                             Years:
# ...

# %%
df['Union'] = df['Unnamed: 1'][5]

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                 Original Data Value
# 1                                                 NaN
# 2                                          Series Id:
# 3                                       Series title:
# 4                                   Unadjusted series
# 5                                              Union:
# 6                                           Industry:
# 7                                         Occupation:
# 8                                                Sex:
# 9                                               Race:
# 10                                     Ethnic Origin:
# 11                                               Age:
# 12                                          Earnings:
# 13                                   Class of Worker:
# 14                                Labor force status:
# 15                                             Years:
# ...

# %%
df['State'] = 'Federal'

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                 Original Data Value
# 1                                                 NaN
# 2                                          Series Id:
# 3                                       Series title:
# 4                                   Unadjusted series
# 5                                              Union:
# 6                                           Industry:
# 7                                         Occupation:
# 8                                                Sex:
# 9                                               Race:
# 10                                     Ethnic Origin:
# 11                                               Age:
# 12                                          Earnings:
# 13                                   Class of Worker:
# 14                                Labor force status:
# 15                                             Years:
# ...

# %%
df['Industry'] =  df['Unnamed: 1'][6]

# %%
df
# Out:
#    Union affiliation data from the Current Population Survey  \
# 0                                 Original Data Value
# 1                                                 NaN
# 2                                          Series Id:
# 3                                       Series title:
# 4                                   Unadjusted series
# 5                                              Union:
# 6                                           Industry:
# 7                                         Occupation:
# 8                                                Sex:
# 9                                               Race:
# 10                                     Ethnic Origin:
# 11                                               Age:
# 12                                          Earnings:
# 13                                   Class of Worker:
# 14                                Labor force status:
# 15                                             Years:
# ...

# %%
df = df.iloc[18:]

# %%
df.drop(columns="Union affiliation data from the Current Population Survey" , inplace=True)
# Out:
# /Users/TekendraMBP/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df.drop(columns='Unnamed: 1')
# Out:
#    Years Labor_Force_in_Thousands                               Series_Title  \
# 18  2000                   122089  (unadj)- Employed wage and salary workers
# 19  2001                   122229  (unadj)- Employed wage and salary workers
# 20  2002                   121826  (unadj)- Employed wage and salary workers
# 21  2003                   122358  (unadj)- Employed wage and salary workers
# 22  2004                   123554  (unadj)- Employed wage and salary workers
# 23  2005                   125889  (unadj)- Employed wage and salary workers
# 24  2006                   128237  (unadj)- Employed wage and salary workers
# 25  2007                   129767  (unadj)- Employed wage and salary workers
# 26  2008                   129377  (unadj)- Employed wage and salary workers
# 27  2009                   124490  (unadj)- Employed wage and salary workers
# 28  2010                   124073  (unadj)- Employed wage and salary workers
# ...

# %%
df.set_index('Years', drop=True, append=False, inplace=True, verify_integrity=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3063             try:
# -> 3064                 return self._engine.get_loc(key)
#    3065             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Years'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-d9681cf8ac79> in <module>()
# ...

# %%
df
# Out:
#       Labor_Force_in_Thousands                               Series_Title  \
# Years
# 2000                    122089  (unadj)- Employed wage and salary workers
# 2001                    122229  (unadj)- Employed wage and salary workers
# 2002                    121826  (unadj)- Employed wage and salary workers
# 2003                    122358  (unadj)- Employed wage and salary workers
# 2004                    123554  (unadj)- Employed wage and salary workers
# 2005                    125889  (unadj)- Employed wage and salary workers
# 2006                    128237  (unadj)- Employed wage and salary workers
# 2007                    129767  (unadj)- Employed wage and salary workers
# 2008                    129377  (unadj)- Employed wage and salary workers
# 2009                    124490  (unadj)- Employed wage and salary workers
# 2010                    124073  (unadj)- Employed wage and salary workers
# 2011                    125187  (unadj)- Employed wage and salary workers
# ...

# %%
Federal_Labor_Force = df

# %%
Federal_Labor_Force
# Out:
#       Labor_Force_in_Thousands                               Series_Title  \
# Years
# 2000                    122089  (unadj)- Employed wage and salary workers
# 2001                    122229  (unadj)- Employed wage and salary workers
# 2002                    121826  (unadj)- Employed wage and salary workers
# 2003                    122358  (unadj)- Employed wage and salary workers
# 2004                    123554  (unadj)- Employed wage and salary workers
# 2005                    125889  (unadj)- Employed wage and salary workers
# 2006                    128237  (unadj)- Employed wage and salary workers
# 2007                    129767  (unadj)- Employed wage and salary workers
# 2008                    129377  (unadj)- Employed wage and salary workers
# 2009                    124490  (unadj)- Employed wage and salary workers
# 2010                    124073  (unadj)- Employed wage and salary workers
# 2011                    125187  (unadj)- Employed wage and salary workers
# ...

# %%
Federal_Labor_Force.to_csv('Federal_Labor_Force.csv')
